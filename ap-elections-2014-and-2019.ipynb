# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/andhra-pradesh-assembly-elections-2014-and-2019/data.csv

# %%
data = pd.read_csv('/kaggle/input/andhra-pradesh-assembly-elections-2014-and-2019/data.csv', encoding = "ISO-8859-1")

data.head(10)
# Out:
#    year          state    ac number      ac name   \
# 0  2014  Andhra Pradesh            1  Ichchapuram
# 1  2014  Andhra Pradesh            1  Ichchapuram
# 2  2014  Andhra Pradesh            1  Ichchapuram
# 3  2014  Andhra Pradesh            1  Ichchapuram
# 4  2014  Andhra Pradesh            1  Ichchapuram
# 5  2014  Andhra Pradesh            1  Ichchapuram
# 6  2014  Andhra Pradesh            1  Ichchapuram
# 7  2019  Andhra Pradesh            1  Ichchapuram
# 8  2019  Andhra Pradesh            1  Ichchapuram
# 9  2019  Andhra Pradesh            1  Ichchapuram
#
#                   candidate name    sex    age   category   party   \
# 0              GANAPA VANAJAKSHI  FEMALE   31.0    GENERAL     IND
# 1                           NOTA     NaN    NaN        NaN    NOTA
# 2               ESWARA RAO KOLLI    MALE   50.0    GENERAL     INC
# 3                    DASARI RAJU    MALE   42.0    GENERAL     JnP
# 4  JANNALA SURYAVARA PRASADA RAO    MALE   67.0    GENERAL     BJP
# 5                 ASHOK BENDALAM    MALE   37.0    GENERAL     TDP
# 6                  PIRIYA SAIRAJ    MALE   42.0    GENERAL   YSRCP
# 7              GANAPA VANAJAKSHI  FEMALE   31.0    GENERAL     IND
# 8                           NOTA     NaN    NaN        NaN    NOTA
# 9               ESWARA RAO KOLLI    MALE   50.0    GENERAL     INC
#
#          symbol    general    postal    total    percentage votes polled   \
# 0           Ring        613       4.0      617                   0.357841
# 1           NOTA       3872       8.0     3880                   2.250280
# 2           Hand       2100      38.0     2138                   1.239974
# 3  Glass Tumbler      10940     183.0    11123                   6.450996
# 4          Lotus       1656     170.0     1826                   1.059023
# 5        Bicycle      79405     587.0    79992                  46.392883
# 6    Ceiling Fan      71931     916.0    72847                  42.249004
# 7           Ring        613       4.0      617                   0.357841
# 8           NOTA       3872       8.0     3880                   2.250280
# 9           Hand       2100      38.0     2138                   1.239974
#
#     total electors
# 0            247941
# 1            247941
# 2            247941
# 3            247941
# 4            247941
# 5            247941
# 6            247941
# 7            247941
# 8            247941
# 9            247941

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4586 entries, 0 to 4585
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       4586 non-null   int64
#  1    state                     4586 non-null   object
#  2    ac number                 4586 non-null   int64
#  3    ac name                   4586 non-null   object
#  4    candidate name            4586 non-null   object
#  5    sex                       4236 non-null   object
#  6    age                       4236 non-null   float64
#  7    category                  4236 non-null   object
#  8    party                     4586 non-null   object
#  9    symbol                    4586 non-null   object
#  10   general                   4586 non-null   int64
#  11   postal                    2658 non-null   float64
#  12   total                     4586 non-null   int64
#  13   percentage votes polled   4586 non-null   float64
#  14   total electors            4586 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 537.5+ KB

# %%
data.shape
# Out:
# (4586, 15)

# %%
data.tail()
# Out:
#       year          state    ac number   ac name            candidate name  \
# 4581  2019  Andhra Pradesh          175    Kuppam         N.S. Thulasinath
# 4582  2019  Andhra Pradesh          175    Kuppam  Nara Chandra Babu Naidu
# 4583  2019  Andhra Pradesh          175    Kuppam    Krishna Chandra Mouli
# 4584  2019  Andhra Pradesh          175    Kuppam                C. Ganesh
# 4585  2019  Andhra Pradesh          175    Kuppam               S. Sathish
#
#       sex    age   category   party       symbol    general    postal   \
# 4581  MALE   40.0    GENERAL     BJP        Lotus       1122      17.0
# 4582  MALE   68.0    GENERAL     TDP      Bicycle      99657     489.0
# 4583  MALE   65.0    GENERAL   YSRCP  Ceiling Fan      69251     173.0
# 4584  MALE   37.0         SC     VCK        Stool        660       1.0
# 4585  MALE   32.0    GENERAL     IND          Bat        486       1.0
#
#        total    percentage votes polled    total electors
# 4581     1139                   0.627552            213329
# 4582   100146                  55.177164            213329
# 4583    69424                  38.250348            213329
# 4584      661                   0.364189            213329
# 4585      487                   0.268321            213329
